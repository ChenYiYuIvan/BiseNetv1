# %% [markdown]
# On Google Colab, reset the runtime and run this command until you get assigned a Tesla T4 GPU or better

# %%
# !nvidia-smi --query-gpu=gpu_name,driver_version,memory.total --format=csv
# Out:
# name, driver_version, memory.total [MiB]
# Tesla T4, 460.32.03, 15109 MiB

# %% [markdown]
# Modify the paths to use the correct one for your project

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/MLDL/Progetto/BiseNetv1

# !pip install wandb

# %env PYTHONPATH=/content/drive/MyDrive/MLDL/Progetto/BiseNetv1

# !python train_adversarial/main_adversarial.py
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/MLDL/Progetto/BiseNetv1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.12.18-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 33.8 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 70.3 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 68.8 MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.1.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.5 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=8a6e7b35f66c4bd33b83f016cf9dfc0df8f98ee55b2e674629582468dfe89868
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.18
# env: PYTHONPATH=/content/drive/MyDrive/MLDL/Progetto/BiseNetv1
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: chyyivan (mldlproj1gr2). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.18
# wandb: Run data is saved locally in /content/drive/MyDrive/MLDL/Progetto/BiseNetv1/wandb/run-20220620_160034-34dccxw7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run wobbly-voice-105
# wandb: ⭐️ View project at https://wandb.ai/mldlproj1gr2/bisenet
# wandb: 🚀 View run at https://wandb.ai/mldlproj1gr2/bisenet/runs/34dccxw7
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 307MB/s]
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100% 171M/171M [00:00<00:00, 246MB/s]
# epoch 0, lr_gen 0.025000, lr_discr 0.000100: 100% 500/500 [04:33<00:00,  1.59it/s, loss_discr_step=0.693105, loss_gen_step=3.130217]loss for generator train : 4.084117
# epoch 0, lr_gen 0.025000, lr_discr 0.000100: 100% 500/500 [04:33<00:00,  1.83it/s, loss_discr_step=0.693105, loss_gen_step=3.130217]
# epoch 1, lr_gen 0.024775, lr_discr 0.000099:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.693136
# epoch 1, lr_gen 0.024775, lr_discr 0.000099: 100% 500/500 [02:45<00:00,  3.03it/s, loss_discr_step=0.698848, loss_gen_step=2.903443]
# loss for generator train : 2.921120
# loss for discriminator train : 0.692219
# epoch 2, lr_gen 0.024550, lr_discr 0.000098: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.674478, loss_gen_step=1.325134]
# loss for generator train : 2.486358
# loss for discriminator train : 0.688096
# epoch 3, lr_gen 0.024324, lr_discr 0.000097: 100% 500/500 [02:44<00:00,  3.04it/s, loss_discr_step=0.707664, loss_gen_step=3.021517]
# loss for generator train : 2.242608
# epoch 4, lr_gen 0.024098, lr_discr 0.000096:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.686425
# epoch 4, lr_gen 0.024098, lr_discr 0.000096: 100% 500/500 [02:46<00:00,  3.68it/s, loss_discr_step=0.682942, loss_gen_step=1.286405]loss for generator train : 2.194222
# epoch 4, lr_gen 0.024098, lr_discr 0.000096: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.682942, loss_gen_step=1.286405]
# loss for discriminator train : 0.685333
# start val!
# precision per pixel for test: 0.614
# mIoU for validation: 0.177
# mIoU per class: [0.71136844 0.18218357 0.60809578 0.0075891  0.         0.02059863
#  0.         0.         0.6900113  0.1466914  0.57089854 0.01588675
#  0.         0.39137133 0.01977489 0.         0.         0.
#  0.        ]
# epoch 5, lr_gen 0.023872, lr_discr 0.000095: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.661966, loss_gen_step=2.224456]
# loss for generator train : 1.919754
# loss for discriminator train : 0.681979
# epoch 6, lr_gen 0.023646, lr_discr 0.000095: 100% 500/500 [02:44<00:00,  3.04it/s, loss_discr_step=0.671651, loss_gen_step=2.763218]
# loss for generator train : 1.918677
# loss for discriminator train : 0.683039
# epoch 7, lr_gen 0.023419, lr_discr 0.000094: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.681384, loss_gen_step=1.521677]
# loss for generator train : 1.812656
# loss for discriminator train : 0.679241
# epoch 8, lr_gen 0.023193, lr_discr 0.000093: 100% 500/500 [02:43<00:00,  3.05it/s, loss_discr_step=0.685726, loss_gen_step=1.987832]
# epoch 9, lr_gen 0.022966, lr_discr 0.000092:   0% 0/500 [00:00<?, ?it/s]loss for generator train : 1.691695
# loss for discriminator train : 0.676427
# epoch 9, lr_gen 0.022966, lr_discr 0.000092: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.683217, loss_gen_step=0.976412]
# loss for generator train : 1.538232
# loss for discriminator train : 0.673523
# start val!
#   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.474
# mIoU for validation: 0.164
# mIoU per class: [3.06810717e-01 1.26737663e-01 6.80727065e-01 7.51180152e-02
#  6.16331086e-04 9.37912240e-02 1.31006858e-03 0.00000000e+00
#  6.65547117e-01 7.21152796e-02 5.85822183e-01 2.15658240e-01
#  0.00000000e+00 2.13117174e-01 8.01261977e-02 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]
# epoch 10, lr_gen 0.022738, lr_discr 0.000091: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.688654, loss_gen_step=1.547252]
# loss for generator train : 1.471916
# loss for discriminator train : 0.673475
# epoch 11, lr_gen 0.022511, lr_discr 0.000090: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.691703, loss_gen_step=1.556189]
# loss for generator train : 1.473989
# loss for discriminator train : 0.675181
# epoch 12, lr_gen 0.022283, lr_discr 0.000089: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.683887, loss_gen_step=1.799189]
# loss for generator train : 1.482738
# epoch 13, lr_gen 0.022055, lr_discr 0.000088:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.674337
# epoch 13, lr_gen 0.022055, lr_discr 0.000088: 100% 500/500 [02:44<00:00,  3.04it/s, loss_discr_step=0.668062, loss_gen_step=1.103068]loss for generator train : 1.402278
#
# loss for discriminator train : 0.668228
# epoch 14, lr_gen 0.021827, lr_discr 0.000087: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.650841, loss_gen_step=1.340105]
# loss for generator train : 1.256568
# loss for discriminator train : 0.665208
# start val!
# precision per pixel for test: 0.637
# mIoU for validation: 0.206
# mIoU per class: [0.7209385  0.1801947  0.69107052 0.09161468 0.01457839 0.1200963
#  0.         0.         0.72224432 0.09919933 0.56922106 0.18560188
#  0.         0.49713757 0.01685125 0.         0.         0.
#  0.        ]
# epoch 15, lr_gen 0.021598, lr_discr 0.000086: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.667933, loss_gen_step=1.655432]loss for generator train : 1.302707
# loss for discriminator train : 0.664092
#
# epoch 16, lr_gen 0.021369, lr_discr 0.000085: 100% 500/500 [02:44<00:00,  3.04it/s, loss_discr_step=0.666410, loss_gen_step=1.772901]
# loss for generator train : 1.348688
# epoch 17, lr_gen 0.021140, lr_discr 0.000085:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.666190
# epoch 17, lr_gen 0.021140, lr_discr 0.000085: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.642523, loss_gen_step=0.685740]
# loss for generator train : 1.200124
# loss for discriminator train : 0.659277
# epoch 18, lr_gen 0.020911, lr_discr 0.000084: 100% 500/500 [02:44<00:00,  3.04it/s, loss_discr_step=0.621432, loss_gen_step=0.998160]
# loss for generator train : 1.221115
# loss for discriminator train : 0.664410
# epoch 19, lr_gen 0.020681, lr_discr 0.000083: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.660219, loss_gen_step=1.090149]
# loss for generator train : 1.301938
# loss for discriminator train : 0.663552
# start val!
#   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.450
# mIoU for validation: 0.163
# epoch 20, lr_gen 0.020451, lr_discr 0.000082:   0% 0/500 [00:00<?, ?it/s]mIoU per class: [0.24781891 0.13944878 0.47287746 0.07820626 0.06092519 0.15928158
#  0.00885262 0.         0.69090536 0.03411738 0.63133236 0.21309903
#  0.         0.292371   0.05908836 0.         0.         0.
#  0.        ]
# epoch 20, lr_gen 0.020451, lr_discr 0.000082: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.678183, loss_gen_step=1.399853]
# loss for generator train : 1.080117
# loss for discriminator train : 0.655098
# epoch 21, lr_gen 0.020221, lr_discr 0.000081: 100% 500/500 [02:45<00:00,  3.03it/s, loss_discr_step=0.664368, loss_gen_step=1.070971]
# epoch 22, lr_gen 0.019991, lr_discr 0.000080:   0% 0/500 [00:00<?, ?it/s]loss for generator train : 1.131482
# loss for discriminator train : 0.651345
# epoch 22, lr_gen 0.019991, lr_discr 0.000080: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.578815, loss_gen_step=0.961809]
# loss for generator train : 1.117866
# loss for discriminator train : 0.647032
# epoch 23, lr_gen 0.019760, lr_discr 0.000079: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.693737, loss_gen_step=1.129815]
# loss for generator train : 1.137178
# loss for discriminator train : 0.655546
# epoch 24, lr_gen 0.019529, lr_discr 0.000078: 100% 500/500 [02:47<00:00,  3.68it/s, loss_discr_step=0.661825, loss_gen_step=1.481329]loss for generator train : 1.169401
# epoch 24, lr_gen 0.019529, lr_discr 0.000078: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.661825, loss_gen_step=1.481329]
# loss for discriminator train : 0.655708
# start val!
#   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.525
# mIoU for validation: 0.189
# mIoU per class: [4.21915714e-01 1.72399084e-01 6.47644389e-01 6.17064562e-02
#  4.06337481e-02 2.06286013e-01 4.97531597e-02 0.00000000e+00
#  7.37113714e-01 1.17258822e-01 6.30364878e-01 2.16552382e-01
#  2.42421267e-04 2.36718296e-01 4.91384767e-02 6.48507322e-03
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]
# epoch 25, lr_gen 0.019297, lr_discr 0.000077: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.669551, loss_gen_step=0.590482]
# loss for generator train : 1.132822
# loss for discriminator train : 0.657205
# epoch 26, lr_gen 0.019066, lr_discr 0.000076: 100% 500/500 [02:44<00:00,  3.03it/s, loss_discr_step=0.641891, loss_gen_step=0.687133]
# loss for generator train : 1.015857
# loss for discriminator train : 0.647671
# epoch 27, lr_gen 0.018833, lr_discr 0.000075: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.614458, loss_gen_step=1.041651]
# loss for generator train : 1.052162
# loss for discriminator train : 0.648836
# epoch 28, lr_gen 0.018601, lr_discr 0.000074: 100% 500/500 [02:45<00:00,  3.66it/s, loss_discr_step=0.621694, loss_gen_step=1.186745]loss for generator train : 1.008670
# loss for discriminator train : 0.644350
# epoch 28, lr_gen 0.018601, lr_discr 0.000074: 100% 500/500 [02:45<00:00,  3.01it/s, loss_discr_step=0.621694, loss_gen_step=1.186745]
# epoch 29, lr_gen 0.018368, lr_discr 0.000073: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.662295, loss_gen_step=1.330047]
# loss for generator train : 0.902438
# loss for discriminator train : 0.645718
# start val!
#   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.425
# mIoU for validation: 0.165
# epoch 30, lr_gen 0.018135, lr_discr 0.000073:   0% 0/500 [00:00<?, ?it/s]mIoU per class: [0.31264079 0.0995438  0.70682618 0.09290498 0.09119426 0.09527573
#  0.04027318 0.         0.4346914  0.03037536 0.62266941 0.24681262
#  0.04792882 0.25188761 0.04440093 0.00814269 0.         0.
#  0.        ]
# epoch 30, lr_gen 0.018135, lr_discr 0.000073: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.709414, loss_gen_step=1.136679]
# loss for generator train : 0.917128
# loss for discriminator train : 0.639537
# epoch 31, lr_gen 0.017902, lr_discr 0.000072: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.721322, loss_gen_step=1.536563]
# loss for generator train : 0.972856
# loss for discriminator train : 0.644168
# epoch 32, lr_gen 0.017668, lr_discr 0.000071: 100% 500/500 [02:43<00:00,  3.69it/s, loss_discr_step=0.595709, loss_gen_step=0.671865]loss for generator train : 1.031968
# epoch 32, lr_gen 0.017668, lr_discr 0.000071: 100% 500/500 [02:44<00:00,  3.05it/s, loss_discr_step=0.595709, loss_gen_step=0.671865]
# loss for discriminator train : 0.648748
# epoch 33, lr_gen 0.017434, lr_discr 0.000070: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.565017, loss_gen_step=0.576486]
# loss for generator train : 0.918042
#   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.642123
# epoch 34, lr_gen 0.017200, lr_discr 0.000069: 100% 500/500 [02:45<00:00,  3.03it/s, loss_discr_step=0.647009, loss_gen_step=1.024765]
# loss for generator train : 0.886866
# loss for discriminator train : 0.638961
# start val!
#   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.562
# mIoU for validation: 0.200
# epoch 35, lr_gen 0.016965, lr_discr 0.000068:   0% 0/500 [00:00<?, ?it/s]mIoU per class: [0.56704741 0.1437513  0.65398243 0.07172535 0.0991126  0.14072426
#  0.05322948 0.         0.6864903  0.04682615 0.53525602 0.20560934
#  0.0732532  0.47064618 0.03633936 0.01133302 0.         0.00085587
#  0.        ]
# epoch 35, lr_gen 0.016965, lr_discr 0.000068: 100% 500/500 [02:46<00:00,  3.49it/s, loss_discr_step=0.804931, loss_gen_step=1.295964]loss for generator train : 0.911060
# epoch 35, lr_gen 0.016965, lr_discr 0.000068: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.804931, loss_gen_step=1.295964]
# epoch 36, lr_gen 0.016730, lr_discr 0.000067:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.644222
# epoch 36, lr_gen 0.016730, lr_discr 0.000067: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.541670, loss_gen_step=0.668032]loss for generator train : 0.876847
# loss for discriminator train : 0.625915
#
# epoch 37, lr_gen 0.016495, lr_discr 0.000066: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.605646, loss_gen_step=0.726504]loss for generator train : 0.829944
#
# loss for discriminator train : 0.632378
# epoch 38, lr_gen 0.016259, lr_discr 0.000065: 100% 500/500 [02:46<00:00,  3.67it/s, loss_discr_step=0.642619, loss_gen_step=1.148719]loss for generator train : 0.869297
# epoch 38, lr_gen 0.016259, lr_discr 0.000065: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.642619, loss_gen_step=1.148719]
# loss for discriminator train : 0.636027
# epoch 39, lr_gen 0.016023, lr_discr 0.000064: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.602378, loss_gen_step=0.724900]
# loss for generator train : 0.815137
# loss for discriminator train : 0.637480
# start val!
# precision per pixel for test: 0.604
# mIoU for validation: 0.223
# mIoU per class: [6.60069687e-01 2.17896260e-01 6.89991747e-01 1.15605051e-01
#  9.00464638e-02 1.75102176e-01 3.58481755e-02 2.67872126e-04
#  6.84675244e-01 6.60025639e-02 5.90270962e-01 3.00789015e-01
#  2.38374555e-02 4.71329875e-01 1.02831697e-01 1.58904449e-02
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]
# epoch 40, lr_gen 0.015786, lr_discr 0.000063: 100% 500/500 [02:47<00:00,  3.61it/s, loss_discr_step=0.660991, loss_gen_step=0.896273]loss for generator train : 0.755431
# loss for discriminator train : 0.628503
# epoch 40, lr_gen 0.015786, lr_discr 0.000063: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.660991, loss_gen_step=0.896273]
# epoch 41, lr_gen 0.015549, lr_discr 0.000062: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.640492, loss_gen_step=0.647908]
#   0% 0/500 [00:00<?, ?it/s]loss for generator train : 0.788963
# loss for discriminator train : 0.641950
# epoch 42, lr_gen 0.015312, lr_discr 0.000061: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.693901, loss_gen_step=1.313741]
# loss for generator train : 0.759217
# loss for discriminator train : 0.630584
# epoch 43, lr_gen 0.015074, lr_discr 0.000060: 100% 500/500 [02:44<00:00,  3.03it/s, loss_discr_step=0.613867, loss_gen_step=1.150216]
# loss for generator train : 0.740724
# loss for discriminator train : 0.630980
# epoch 44, lr_gen 0.014836, lr_discr 0.000059: 100% 500/500 [02:45<00:00,  3.01it/s, loss_discr_step=0.654918, loss_gen_step=1.086684]loss for generator train : 0.865090
#
# loss for discriminator train : 0.642334
# start val!
# precision per pixel for test: 0.503
# mIoU for validation: 0.204
# epoch 45, lr_gen 0.014597, lr_discr 0.000058:   0% 0/500 [00:00<?, ?it/s]mIoU per class: [3.70638408e-01 1.66901250e-01 5.97155988e-01 9.38535497e-02
#  7.03548742e-02 1.49877548e-01 4.00831924e-02 6.61876143e-04
#  6.50122425e-01 4.80772854e-02 6.84592819e-01 3.37018921e-01
#  1.35664339e-02 4.92755892e-01 8.96842981e-02 5.00486334e-02
#  0.00000000e+00 2.34248027e-02 0.00000000e+00]
# epoch 45, lr_gen 0.014597, lr_discr 0.000058: 100% 500/500 [02:48<00:00,  2.97it/s, loss_discr_step=0.626092, loss_gen_step=0.587482]
# loss for generator train : 0.855785
# loss for discriminator train : 0.634774
# epoch 46, lr_gen 0.014358, lr_discr 0.000057: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.670536, loss_gen_step=0.605364]
# loss for generator train : 0.695562
# loss for discriminator train : 0.633394
# epoch 47, lr_gen 0.014118, lr_discr 0.000056: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.606407, loss_gen_step=0.576196]
# loss for generator train : 0.663942
# loss for discriminator train : 0.633656
# epoch 48, lr_gen 0.013879, lr_discr 0.000056: 100% 500/500 [02:46<00:00,  3.68it/s, loss_discr_step=0.668365, loss_gen_step=0.652303]loss for generator train : 0.726684
# loss for discriminator train : 0.633462
# epoch 48, lr_gen 0.013879, lr_discr 0.000056: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.668365, loss_gen_step=0.652303]
# epoch 49, lr_gen 0.013638, lr_discr 0.000055: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.701495, loss_gen_step=1.051636]
# loss for generator train : 0.683971
# loss for discriminator train : 0.633110
# start val!
# precision per pixel for test: 0.523
# mIoU for validation: 0.224
# mIoU per class: [0.39137983 0.15746912 0.55692907 0.13514587 0.14862211 0.17377527
#  0.07569418 0.01903362 0.7419262  0.04480541 0.65816444 0.35609577
#  0.02937648 0.54433617 0.13470138 0.08031269 0.         0.00930249
#  0.        ]
# epoch 50, lr_gen 0.013397, lr_discr 0.000054: 100% 500/500 [02:45<00:00,  3.68it/s, loss_discr_step=0.644256, loss_gen_step=0.792736]loss for generator train : 0.739587
# epoch 50, lr_gen 0.013397, lr_discr 0.000054: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.644256, loss_gen_step=0.792736]
# epoch 51, lr_gen 0.013156, lr_discr 0.000053:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.633924
# epoch 51, lr_gen 0.013156, lr_discr 0.000053: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.638670, loss_gen_step=0.759216]
# loss for generator train : 0.745535
# loss for discriminator train : 0.629989
# epoch 52, lr_gen 0.012914, lr_discr 0.000052: 100% 500/500 [02:45<00:00,  3.01it/s, loss_discr_step=0.564755, loss_gen_step=0.592166]loss for generator train : 0.649932
# loss for discriminator train : 0.630895
#
# epoch 53, lr_gen 0.012672, lr_discr 0.000051: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.590768, loss_gen_step=0.475055]
# loss for generator train : 0.664444
# loss for discriminator train : 0.624358
# epoch 54, lr_gen 0.012429, lr_discr 0.000050: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.640726, loss_gen_step=0.571338]
# loss for generator train : 0.639022
# loss for discriminator train : 0.624793
# start val!
# precision per pixel for test: 0.547
# mIoU for validation: 0.235
# mIoU per class: [0.46873176 0.15030225 0.68611123 0.139408   0.12141574 0.11308312
#  0.05346633 0.00816241 0.72415483 0.03493119 0.66387861 0.28394398
#  0.08598496 0.63845397 0.16825378 0.08008489 0.         0.05338545
#  0.        ]
# epoch 55, lr_gen 0.012185, lr_discr 0.000049: 100% 500/500 [02:48<00:00,  2.96it/s, loss_discr_step=0.637699, loss_gen_step=0.617545]
# epoch 56, lr_gen 0.011941, lr_discr 0.000048:   0% 0/500 [00:00<?, ?it/s]loss for generator train : 0.622580
# loss for discriminator train : 0.617653
# epoch 56, lr_gen 0.011941, lr_discr 0.000048: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.605171, loss_gen_step=0.468679]
# loss for generator train : 0.601959
# loss for discriminator train : 0.617365
# epoch 57, lr_gen 0.011697, lr_discr 0.000047: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.627421, loss_gen_step=0.622353]
# loss for generator train : 0.609482
# loss for discriminator train : 0.618713
# epoch 58, lr_gen 0.011452, lr_discr 0.000046: 100% 500/500 [02:46<00:00,  3.66it/s, loss_discr_step=0.592998, loss_gen_step=0.468175]loss for generator train : 0.615401
# loss for discriminator train : 0.621981
# epoch 58, lr_gen 0.011452, lr_discr 0.000046: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.592998, loss_gen_step=0.468175]
# epoch 59, lr_gen 0.011206, lr_discr 0.000045: 100% 500/500 [02:46<00:00,  2.99it/s, loss_discr_step=0.642967, loss_gen_step=0.497778]
# loss for generator train : 0.603670
# loss for discriminator train : 0.617806
# start val!
# precision per pixel for test: 0.607
# mIoU for validation: 0.252
# mIoU per class: [0.59687265 0.1771911  0.73770327 0.14568746 0.10166993 0.14561483
#  0.06114089 0.020974   0.7876883  0.05075872 0.63378122 0.29696737
#  0.10810368 0.64067655 0.15313123 0.05483595 0.         0.07329033
#  0.        ]
# epoch 60, lr_gen 0.010960, lr_discr 0.000044: 100% 500/500 [02:48<00:00,  3.66it/s, loss_discr_step=0.586076, loss_gen_step=0.664567]loss for generator train : 0.569826
# epoch 60, lr_gen 0.010960, lr_discr 0.000044: 100% 500/500 [02:49<00:00,  2.96it/s, loss_discr_step=0.586076, loss_gen_step=0.664567]
# loss for discriminator train : 0.620766
# epoch 61, lr_gen 0.010713, lr_discr 0.000043: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.613716, loss_gen_step=0.804403]
# epoch 62, lr_gen 0.010465, lr_discr 0.000042:   0% 0/500 [00:00<?, ?it/s]loss for generator train : 0.559008
# loss for discriminator train : 0.615584
# epoch 62, lr_gen 0.010465, lr_discr 0.000042: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.691096, loss_gen_step=1.017079]
# loss for generator train : 0.592292
# loss for discriminator train : 0.620009
# epoch 63, lr_gen 0.010217, lr_discr 0.000041: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.519293, loss_gen_step=0.704582]
# loss for generator train : 0.594327
#   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.601985
# epoch 64, lr_gen 0.009968, lr_discr 0.000040: 100% 500/500 [02:44<00:00,  3.03it/s, loss_discr_step=0.705657, loss_gen_step=0.675640]
# loss for generator train : 0.544930
# loss for discriminator train : 0.612171
# start val!
# epoch 65, lr_gen 0.009719, lr_discr 0.000039:   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.602
# mIoU for validation: 0.244
# mIoU per class: [0.57857722 0.17865265 0.73810016 0.15449367 0.12947222 0.20064545
#  0.06841682 0.04188385 0.78935794 0.08776953 0.63113084 0.36189935
#  0.04310185 0.35835006 0.14243995 0.06796823 0.         0.06072537
#  0.        ]
# epoch 65, lr_gen 0.009719, lr_discr 0.000039: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.646305, loss_gen_step=0.543076]
# loss for generator train : 0.542545
# loss for discriminator train : 0.615811
# epoch 66, lr_gen 0.009468, lr_discr 0.000038: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.613472, loss_gen_step=0.532466]
# loss for generator train : 0.547472
#   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.628404
# epoch 67, lr_gen 0.009217, lr_discr 0.000037: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.650576, loss_gen_step=0.655372]
# loss for generator train : 0.537536
# loss for discriminator train : 0.613197
# epoch 68, lr_gen 0.008966, lr_discr 0.000036: 100% 500/500 [02:45<00:00,  3.03it/s, loss_discr_step=0.578665, loss_gen_step=0.426398]
# loss for generator train : 0.543427
# epoch 69, lr_gen 0.008713, lr_discr 0.000035:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.629296
# epoch 69, lr_gen 0.008713, lr_discr 0.000035: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.570541, loss_gen_step=0.540572]
# loss for generator train : 0.538757
# loss for discriminator train : 0.614102
# start val!
# precision per pixel for test: 0.567
# mIoU for validation: 0.232
# mIoU per class: [0.46565477 0.19858516 0.73713333 0.15335449 0.13986348 0.15403892
#  0.09283797 0.01909107 0.79967892 0.06514709 0.65979473 0.33357347
#  0.09524235 0.31061096 0.11147838 0.02291665 0.         0.05147732
#  0.        ]
# epoch 70, lr_gen 0.008460, lr_discr 0.000034: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.634855, loss_gen_step=0.558115]
# loss for generator train : 0.515296
# loss for discriminator train : 0.612629
# epoch 71, lr_gen 0.008205, lr_discr 0.000033: 100% 500/500 [02:48<00:00,  2.97it/s, loss_discr_step=0.541460, loss_gen_step=0.414136]
# loss for generator train : 0.559254
# loss for discriminator train : 0.627945
# epoch 72, lr_gen 0.007950, lr_discr 0.000032: 100% 500/500 [02:45<00:00,  3.01it/s, loss_discr_step=0.515539, loss_gen_step=0.421874]
# loss for generator train : 0.532684
# loss for discriminator train : 0.620177
# epoch 73, lr_gen 0.007694, lr_discr 0.000031: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.602330, loss_gen_step=0.671555]
# loss for generator train : 0.556901
# loss for discriminator train : 0.635365
# epoch 74, lr_gen 0.007437, lr_discr 0.000030: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.684651, loss_gen_step=0.484553]
# loss for generator train : 0.533465
# loss for discriminator train : 0.620159
# start val!
# precision per pixel for test: 0.647
# mIoU for validation: 0.259
# mIoU per class: [0.69452105 0.20226809 0.73469372 0.15002283 0.14057154 0.15890645
#  0.05859531 0.02922186 0.78618055 0.07901463 0.64551046 0.3217835
#  0.10697744 0.57214679 0.13654729 0.03038407 0.         0.0699357
#  0.        ]
# epoch 75, lr_gen 0.007179, lr_discr 0.000029: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.665972, loss_gen_step=0.422702]
# loss for generator train : 0.514563
# loss for discriminator train : 0.620795
# epoch 76, lr_gen 0.006920, lr_discr 0.000028: 100% 500/500 [02:47<00:00,  3.66it/s, loss_discr_step=0.575233, loss_gen_step=0.475731]loss for generator train : 0.511494
# loss for discriminator train : 0.616143
# epoch 76, lr_gen 0.006920, lr_discr 0.000028: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.575233, loss_gen_step=0.475731]
# epoch 77, lr_gen 0.006660, lr_discr 0.000027: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.622989, loss_gen_step=0.423655]
# loss for generator train : 0.496224
# loss for discriminator train : 0.618058
# epoch 78, lr_gen 0.006399, lr_discr 0.000026: 100% 500/500 [02:45<00:00,  3.02it/s, loss_discr_step=0.614426, loss_gen_step=0.549584]
# loss for generator train : 0.489628
# loss for discriminator train : 0.609073
# epoch 79, lr_gen 0.006137, lr_discr 0.000025: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.526735, loss_gen_step=0.330694]
# loss for generator train : 0.483831
# loss for discriminator train : 0.613521
# start val!
# precision per pixel for test: 0.645
# mIoU for validation: 0.267
# mIoU per class: [0.67255459 0.18438834 0.73019962 0.18776375 0.12463766 0.20689156
#  0.07015875 0.01622998 0.79414034 0.14016344 0.66949586 0.36644553
#  0.0938122  0.44305208 0.20623306 0.09344204 0.         0.078122
#  0.        ]
# epoch 80, lr_gen 0.005873, lr_discr 0.000023: 100% 500/500 [02:48<00:00,  2.96it/s, loss_discr_step=0.691885, loss_gen_step=0.514274]
# loss for generator train : 0.475987
# epoch 81, lr_gen 0.005608, lr_discr 0.000022:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.608440
# epoch 81, lr_gen 0.005608, lr_discr 0.000022: 100% 500/500 [02:48<00:00,  2.97it/s, loss_discr_step=0.558995, loss_gen_step=0.533407]
# loss for generator train : 0.506537
# loss for discriminator train : 0.608711
# epoch 82, lr_gen 0.005342, lr_discr 0.000021: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.673408, loss_gen_step=0.402015]
# loss for generator train : 0.504604
# loss for discriminator train : 0.606684
# epoch 83, lr_gen 0.005074, lr_discr 0.000020: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.543668, loss_gen_step=0.417482]loss for generator train : 0.475447
# loss for discriminator train : 0.612592
#
# epoch 84, lr_gen 0.004804, lr_discr 0.000019: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.674956, loss_gen_step=0.465834]
# loss for generator train : 0.468772
# loss for discriminator train : 0.618343
# start val!
#   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.608
# mIoU for validation: 0.252
# epoch 85, lr_gen 0.004533, lr_discr 0.000018:   0% 0/500 [00:00<?, ?it/s]mIoU per class: [0.59193922 0.16485697 0.73648487 0.16521186 0.11616748 0.2327215
#  0.08929858 0.02492175 0.79798502 0.06035053 0.63837658 0.37980451
#  0.1213568  0.43208975 0.14000017 0.02979837 0.         0.06847255
#  0.        ]
# epoch 85, lr_gen 0.004533, lr_discr 0.000018: 100% 500/500 [02:49<00:00,  2.95it/s, loss_discr_step=0.660805, loss_gen_step=0.488248]
# loss for generator train : 0.469935
# loss for discriminator train : 0.615561
# epoch 86, lr_gen 0.004260, lr_discr 0.000017: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.646011, loss_gen_step=0.550450]
# loss for generator train : 0.473706
# loss for discriminator train : 0.617351
# epoch 87, lr_gen 0.003986, lr_discr 0.000016: 100% 500/500 [02:47<00:00,  3.50it/s, loss_discr_step=0.548382, loss_gen_step=0.267662]loss for generator train : 0.464723
# epoch 87, lr_gen 0.003986, lr_discr 0.000016: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.548382, loss_gen_step=0.267662]
# epoch 88, lr_gen 0.003709, lr_discr 0.000015:   0% 0/500 [00:00<?, ?it/s]loss for discriminator train : 0.619437
# epoch 88, lr_gen 0.003709, lr_discr 0.000015: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.553848, loss_gen_step=0.521984]
# loss for generator train : 0.448590
# loss for discriminator train : 0.616375
# epoch 89, lr_gen 0.003429, lr_discr 0.000014: 100% 500/500 [02:46<00:00,  3.01it/s, loss_discr_step=0.650875, loss_gen_step=0.428576]
# loss for generator train : 0.459507
# loss for discriminator train : 0.613558
# start val!
# epoch 90, lr_gen 0.003147, lr_discr 0.000013:   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.615
# mIoU for validation: 0.253
# mIoU per class: [0.60107737 0.17234195 0.68994371 0.16147375 0.10527762 0.21136376
#  0.09559785 0.02138374 0.81090619 0.0632533  0.64548432 0.36597814
#  0.07374783 0.50870759 0.16579872 0.04589056 0.         0.0756037
#  0.        ]
# epoch 90, lr_gen 0.003147, lr_discr 0.000013: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.589327, loss_gen_step=0.429270]
#   0% 0/500 [00:00<?, ?it/s]loss for generator train : 0.457789
# loss for discriminator train : 0.611613
# epoch 91, lr_gen 0.002863, lr_discr 0.000011: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.647521, loss_gen_step=0.536815]
# loss for generator train : 0.452119
# loss for discriminator train : 0.617010
# epoch 92, lr_gen 0.002575, lr_discr 0.000010: 100% 500/500 [02:47<00:00,  3.68it/s, loss_discr_step=0.720586, loss_gen_step=0.590359]loss for generator train : 0.459601
# loss for discriminator train : 0.609368
# epoch 92, lr_gen 0.002575, lr_discr 0.000010: 100% 500/500 [02:48<00:00,  2.97it/s, loss_discr_step=0.720586, loss_gen_step=0.590359]
# epoch 93, lr_gen 0.002283, lr_discr 0.000009: 100% 500/500 [02:48<00:00,  2.97it/s, loss_discr_step=0.610062, loss_gen_step=0.363807]
# loss for generator train : 0.453198
# loss for discriminator train : 0.611158
# epoch 94, lr_gen 0.001987, lr_discr 0.000008: 100% 500/500 [02:46<00:00,  3.00it/s, loss_discr_step=0.579610, loss_gen_step=0.405645]
# loss for generator train : 0.426906
# loss for discriminator train : 0.615641
# start val!
#   0% 0/500 [00:00<?, ?it/s]precision per pixel for test: 0.604
# mIoU for validation: 0.256
# mIoU per class: [0.57533578 0.17370523 0.68467291 0.15945002 0.1479594  0.1897728
#  0.08582016 0.0365051  0.78899585 0.06178207 0.65518156 0.36621649
#  0.09227419 0.50036895 0.17980453 0.09297788 0.         0.07531105
#  0.        ]
# epoch 95, lr_gen 0.001687, lr_discr 0.000007: 100% 500/500 [02:48<00:00,  2.97it/s, loss_discr_step=0.559046, loss_gen_step=0.501738]
# loss for generator train : 0.450370
# loss for discriminator train : 0.611790
# epoch 96, lr_gen 0.001380, lr_discr 0.000006: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.551284, loss_gen_step=0.430872]
# loss for generator train : 0.451612
# loss for discriminator train : 0.611947
# epoch 97, lr_gen 0.001065, lr_discr 0.000004: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.606390, loss_gen_step=0.524483]
# loss for generator train : 0.433162
# loss for discriminator train : 0.612183
# epoch 98, lr_gen 0.000739, lr_discr 0.000003: 100% 500/500 [02:47<00:00,  2.99it/s, loss_discr_step=0.574133, loss_gen_step=0.350798]
# loss for generator train : 0.443728
# loss for discriminator train : 0.611438
# epoch 99, lr_gen 0.000396, lr_discr 0.000002: 100% 500/500 [02:47<00:00,  2.98it/s, loss_discr_step=0.556457, loss_gen_step=0.428105]
# loss for generator train : 0.447108
# loss for discriminator train : 0.612222
# start val!
# precision per pixel for test: 0.602
# mIoU for validation: 0.257
# mIoU per class: [0.57897775 0.15515089 0.70195709 0.14452703 0.12781675 0.20164444
#  0.09273705 0.03260594 0.78428825 0.05218274 0.65873298 0.38407411
#  0.11378275 0.53009019 0.17816413 0.07947294 0.         0.06445916
#  0.        ]
# start val!
# precision per pixel for test: 0.602
# mIoU for validation: 0.257
# mIoU per class: [0.57897775 0.15515089 0.70195709 0.14452703 0.12781675 0.20164444
#  0.09273705 0.03260594 0.78428825 0.05218274 0.65873298 0.38407411
#  0.11378275 0.53009019 0.17816413 0.07947294 0.         0.06445916
#  0.        ]
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb:      IoU_bicycle ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:     IoU_building ▅▆▇▁▆▇▆▇▄▃▇██████▇▇▇
# wandb:          IoU_bus ▁▁▁▁▁▂▂▂▅▇▇▅▆▃▃█▃▄█▇
# wandb:          IoU_car ▄▁▆▂▁▂▅▅▆▆██▃▃▇▅▅▆▆▆
# wandb:        IoU_fence ▁▁▂▄▃▅▆▅▄█▇▆▇██▇▆▆█▇
# wandb:        IoU_light ▁▁▁▂▅▄▅▄▄▇▅▅▆█▅▆██▇█
# wandb:   IoU_motorcycle ▁▁▁▁▁▁▁▁▃▂▆█▆▆▇█▇██▇
# wandb:       IoU_person ▁▅▄▅▅▅▅▆▇▇▆▆█▇▇█████
# wandb:         IoU_pole ▁▃▄▆▇▃▅▆▅▆▄▅▇▅▆▇█▇▇▇
# wandb:        IoU_rider ▁▁▁▁▁▄▅▂▂▃▆▇▃▆▇▆█▅▆█
# wandb:         IoU_road █▂█▁▄▂▆▇▃▃▄▆▆▄█▇▆▆▆▆
# wandb:     IoU_sidewalk ▆▃▆▃▅▁▄█▅▄▄▆▆▇▇▆▅▅▅▄
# wandb:         IoU_sign ▁▁▁▁▁▁▁▁▁▄▂▅█▄▆▄▅▅▇▆
# wandb:          IoU_sky ▃▃▃▆▅▅▁▄█▇▇▆▅▇▆▇▆▆▇▇
# wandb:      IoU_terrain █▄▅▁▆▁▂▃▂▂▁▂▄▃▄█▃▃▃▂
# wandb:        IoU_train ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:        IoU_truck ▁▃▁▃▂▂▂▄▄▅▇▆▆▄▅█▆▇▇▇
# wandb:   IoU_vegetation ▆▅▆▆▇▁▆▆▅▇▆█████████
# wandb:         IoU_wall ▁▄▄▄▃▄▃▅▄▆▆▆▇▇▇█▇▇▇▆
# wandb:         accuracy ▇▃█▂▄▁▅▇▃▄▅▇▇▅██▇▇▇▇
# wandb:            epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:   loss_adv_epoch ▁▁▂▂▂▂▃▃▃▄▃▄▄▄▅▅▅▅▅▅▆▆▆▆▇█▇▆▇▆▇▇██▇▇▇▇▇█
# wandb:    loss_adv_step ▂▂▂▂▂▂▃▄▃▃▁▄▂▃▅▂▅▅▂▃▃▄▅▆▅▇█▅▆▆▅█▅▅▃▅▂▅▇▅
# wandb: loss_discr_epoch ██▇▇▆▇▆▅▅▄▅▅▄▄▄▄▃▃▄▃▃▃▂▃▂▁▃▃▃▄▂▂▂▂▂▂▂▂▂▂
# wandb:  loss_discr_step ██▇▇▇▇▇▆▅▅▇▅▆▅▆▅▄▆█▅▆▅▃▇▆▁▅▄▃▄▂▃▅▅▇█▇▆▄▆
# wandb:   loss_gen_epoch █▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    loss_gen_step █▅▃▃▂▂▃▄▂▂▃▃▂▂▂▂▂▂▂▂▃▁▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   loss_seg_epoch █▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    loss_seg_step █▅▃▃▂▂▃▄▂▂▃▃▂▂▂▂▂▂▂▂▃▁▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:             mIoU ▂▁▄▁▃▁▃▅▄▅▆▇▆▆▇█▇▇▇▇
# wandb:
# wandb: Run summary:
# wandb:      IoU_bicycle 0.0
# wandb:     IoU_building 0.70196
# wandb:          IoU_bus 0.07947
# wandb:          IoU_car 0.53009
# wandb:        IoU_fence 0.12782
# wandb:        IoU_light 0.09274
# wandb:   IoU_motorcycle 0.06446
# wandb:       IoU_person 0.38407
# wandb:         IoU_pole 0.20164
# wandb:        IoU_rider 0.11378
# wandb:         IoU_road 0.57898
# wandb:     IoU_sidewalk 0.15515
# wandb:         IoU_sign 0.03261
# wandb:          IoU_sky 0.65873
# wandb:      IoU_terrain 0.05218
# wandb:        IoU_train 0.0
# wandb:        IoU_truck 0.17816
# wandb:   IoU_vegetation 0.78429
# wandb:         IoU_wall 0.14453
# wandb:         accuracy 0.60213
# wandb:            epoch 99
# wandb:   loss_adv_epoch 0.00099
# wandb:    loss_adv_step 0.00099
# wandb: loss_discr_epoch 0.61222
# wandb:  loss_discr_step 0.55646
# wandb:   loss_gen_epoch 0.44711
# wandb:    loss_gen_step 0.42811
# wandb:   loss_seg_epoch 0.44612
# wandb:    loss_seg_step 0.42712
# wandb:             mIoU 0.25688
# wandb:         max_mIoU 0.26725
# wandb:
# wandb: Synced wobbly-voice-105: https://wandb.ai/mldlproj1gr2/bisenet/runs/34dccxw7
# wandb: Synced 5 W&B file(s), 1 media file(s), 21 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220620_160034-34dccxw7/logs
